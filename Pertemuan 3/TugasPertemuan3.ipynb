# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Generate universe variables
#TB = Tugas Besar
x_tugas = (np.arange(0, 4, 1))
x_quiz = (np.arange(300, 600, 1))
x_TB  = (np.arange(0, 700, 1))

# %%
# Generate fuzzy membership functions
ipk_low = fuzz.trapmf(x_ipk,[0, 0, 1, 2])
ipk_middle = fuzz.trapmf(x_ipk,[1, 2, 3, 4])
ipk_high = fuzz.trapmf(x_ipk,[3, 4, 4, 4])

toefl_low = fuzz.trapmf(x_toefl,[0, 300, 420, 480])
toefl_middle = fuzz.trimf(x_toefl,[420, 480, 540])
toefl_high = fuzz.trapmf(x_toefl,[480, 540, 600, 600])

tpa_low = fuzz.trapmf(x_tpa,[0, 0, 300, 450])
tpa_middle = fuzz.trapmf(x_tpa,[300, 450, 600, 700])
tpa_high = fuzz.trapmf(x_tpa,[600, 700, 700, 700])

# %%
R = 30
S = 60
T = 100

# %%
# Visualize these universes and membership functions//membuat visualisasi grafik
fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=4, figsize=(8, 10))

ax0.plot(x_ipk, ipk_rendah, 'b', linewidth=1.5, label='low')
ax0.plot(x_ipk, ipk_sedang, 'g', linewidth=1.5, label='middle')
ax0.plot(x_ipk, ipk_tinggi, 'r', linewidth=1.5, label='high')
ax0.set_title('Index Tugas')
ax0.legend()

ax1.plot(x_toefl, toefl_rendah, 'b', linewidth=1.5, label='low')
ax1.plot(x_toefl, toefl_sedang, 'g', linewidth=1.5, label='middle')
ax1.plot(x_toefl, toefl_tinggi, 'r', linewidth=1.5, label='high')
ax1.set_title('Index Quiz')
ax1.legend()

ax2.plot(x_tpa, tpa_rendah, 'b', linewidth=1.5, label='low')
ax2.plot(x_tpa, tpa_sedang, 'g', linewidth=1.5, label='middle')
ax2.plot(x_tpa, tpa_tinggi, 'r', linewidth=1.5, label='high')
ax2.set_title('Index TugasBesar')
ax2.legend()

ax3.plot([3, 3],[0, T], 'b', linewidth=1.5, label= 'low')
ax3.plot([2, 2],[0, S], 'g', linewidth=1.5, label= 'middle')
ax3.plot([1, 1],[0, R], 'r', linewidth=1.5, label= 'high')
ax3.set_title('Singleton Sugeno')
ax3.legend()
